# %%
import numpy as np
import os
import random
import tensorflow as tf
import pickle
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1130 03:26:10.425972  9616 __init__.py:690]
#
#   TensorFlow's `tf-nightly` package will soon be updated to TensorFlow 2.0.
#
#   Please upgrade your code to TensorFlow 2.0:
#     * https://www.tensorflow.org/beta/guide/migration_guide
#
#   Or install the latest stable TensorFlow 1.X release:
#     * `pip install -U "tensorflow==1.*"`
#
#   Otherwise your code may be broken by the change.

# %%
import cv2
images = []
with open("dtd/labels/labels_joint_anno.txt", "r") as f:
    lines = f.readlines()
    for line in lines:
        img = cv2.imread("dtd/images/" + line.split(' ')[0])
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        img  = cv2.resize(img, dsize=(256, 256), interpolation=cv2.INTER_CUBIC)
        images.append(img)

# %%
plt.imshow(images[idx])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-f50d83380813> in <module>
#       1 idx = 125
# ----> 2 plt.imshow(images[idx])
#       3 plt.show()
#
# IndexError: list index out of range

# %%
idx = random.randint(0, len(images))
# idx = 4834
plt.imshow(images[idx])
plt.show()
print(images.shape)
# Out:
# (125, 256, 256, 3)

# %%
images = np.concatenate(images)
images = images.reshape((125, 256, 256, 3))

# %%
images = images.reshape((5640,256,256,3))

# %%
image = mpimg.imread("texture.jpg")
with open('texture.pkl','wb') as f:
    pickle.dump(image, f, protocol = 2)

# %%
import cv2
images = []
with open("dtd/labels/labels_joint_anno.txt", "r") as f:
    lines = f.readlines()
    for line in lines:
        if("braided" in line):
            img = cv2.imread("dtd/images/" + line.split(' ')[0])
            img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
            img  = cv2.resize(img, dsize=(256, 256), interpolation=cv2.INTER_CUBIC)
            images.append(img)

# %%
max([v.shape[1] for v in images])
# Out:
# 900

# %%
asd=[v.shape[0] < 256 for v in images]
asd[1] = True
np.argwhere(asd)
# Out:
# array([[   1],
#        [4834]], dtype=int64)

# %%
x = images[4834]
x = np.resize(x, (256,313,3))

# %%
imgs = [np.resize(v, (256, 256, 3)) for v in images]
#     images.append(np.reshape(img, (256, 256, 3)))

# np.reshape(imgs[0], (255,255,3))

# %%
import cv2
x = cv2.imread("dtd/images/interlaced/interlaced_0182.jpg")
x = cv2.cvtColor(x, cv2.COLOR_RGB2BGR)
x  = cv2.resize(x, dsize=(256, 256), interpolation=cv2.INTER_CUBIC)
# x.resize(256, 256)
plt.imshow(x)
plt.show()
print(x.shape)
# Out:
# (256, 256, 3)

# %%
print(imgs)
